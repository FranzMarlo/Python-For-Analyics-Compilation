# %% [markdown]
# #Numbers and Strings
#
# This notebook contains additional practice on numbers and strings. You will have 6 tasks for self-assessment. For each task, see if you can predict the answer instead of just running the code.

# %% [markdown]
# # Task 1
#
# What is the result to the following expression?
#
# 3-6/3
#
# Is it positive 1 or negative 1?

# %% [markdown]
# Positive

# %%
3-6/3
# Out:
# 1.0

# %% [markdown]
# # Task 2
#
# What is the result to the following expression?
#
# 5**2//4
#
# Choices:
#
# a.) 1.25
#
# b.) 2.5
#
# c.) 6
#
# d.) 6.25

# %% [markdown]
# C. 6

# %%
5**2//4
# Out:
# 6

# %% [markdown]
# # Task 3
#
# What is the result to the following expression?
#
# 10 % 3
#
# Choices:
#
# a.) 0
#
# b.) 1
#
# c.) 2
#
# d.) 3

# %% [markdown]
# B. 1

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# # Task 4
#
# You have only 3 lines of code. Which line will throw an error and why?
#
# print(“string”)
#
# print(‘string’)
#
# print(string)

# %% [markdown]
# The line 3 will throw an error because the string in the line 3 is not defined as a variable.

# %%
string = "string"

print("string")

print('string')

print(string)
# Out:
# string
# string
# string

# %% [markdown]
# # Task 5
#
# You have two string variables a and b:
#
# a = “Hello, I am a ”
#
# b = “Data Analyst”
#
# How do you join these two together in variable c without copy-pasting/retyping the words?

# %%
a = "Hello, I am a "

b = "Data Analyst"

c = a + b

print(c)
# Out:
# Hello, I am a Data Analyst

# %% [markdown]
# # Task 6
#
# You have one string variable a and one numerical variable b:
#
# a = “I studied Data Analytics in the year ”
#
# b = 2021
#
# How do you join these two together in variable c without copy-pasting/retyping the words?

# %%
a = "I studied Data Analytics in the year "

b = 2021

c = a + str(b)

print(c)
# Out:
# I studied Data Analytics in the year 2021
